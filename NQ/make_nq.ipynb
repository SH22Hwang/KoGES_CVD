# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc

# 기본 글꼴을 NanumGothic으로 변경
rc("font", family="NanumGothic")

AS1_01_EXAMINEE = pd.read_csv("./AS1_01_EXAMINEE.csv", index_col=0)
AS1_03_DRSM = pd.read_csv("./AS1_03_DRSM.csv", index_col=0)
AS1_17_FFQWEIGHT = pd.read_csv("AS1_17_FFQWEIGHT.csv", index_col=0)


df = pd.DataFrame(index=AS1_01_EXAMINEE.index)

# %%
AS1_17_FFQWEIGHT.dropna(inplace=True)

# %%
AS1_06_DISEASE = pd.read_csv("./AS1_06_DISEASE.csv", index_col=0, encoding='utf-8')
AS1_07_TREAT = pd.read_csv("./AS1_07_TREAT.csv", index_col=0, encoding='utf-8')
AS1_08_DRUG = pd.read_csv("./AS1_08_DRUG.csv", index_col=0, encoding='utf-8')

disease = AS1_06_DISEASE[["AS1_PDMI", "AS1_PDCH", "AS1_PDCD", "AS1_PDCV"]]
treat = AS1_07_TREAT[["AS1_TRTMI", "AS1_TRTCH", "AS1_TRTCD", "AS1_TRTCV"]]
drug = AS1_08_DRUG[['AS1_DRUGSTKCU']]

dependent = pd.concat([disease, treat, drug])
dependent.info()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File parsers.pyx:1120, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File parsers.pyx:1272, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File parsers.pyx:1285, in pandas._libs.parsers.TextReader._string_convert()
#
# File parsers.pyx:1535, in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc0 in position 0: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 AS1_06_DISEASE = pd.read_csv("./AS1_06_DISEASE.csv", index_col=0, encoding='utf-8')
#       2 AS1_07_TREAT = pd.read_csv("./AS1_07_TREAT.csv", index_col=0, encoding='utf-8')
# ...

# %%
dependent.head()
# Out:
#                AS1_PDMI  AS1_PDCH  AS1_PDCD  AS1_PDCV  AS1_TRTMI  AS1_TRTCH  \
# DIST_ID
# NIH23B1298125       1.0       1.0       1.0       1.0        NaN        NaN
# NIH23B1159376       1.0       1.0       1.0       1.0        NaN        NaN
# NIH23B1785393       1.0       1.0       1.0       1.0        NaN        NaN
# NIH23B1463054       1.0       1.0       1.0       1.0        NaN        NaN
# NIH23B1751168       1.0       1.0       1.0       1.0        NaN        NaN
#
#                AS1_TRTCD  AS1_TRTCV  AS1_DRUGSTKCU
# DIST_ID
# NIH23B1298125        NaN        NaN            NaN
# NIH23B1159376        NaN        NaN            NaN
# NIH23B1785393        NaN        NaN            NaN
# NIH23B1463054        NaN        NaN            NaN
# NIH23B1751168        NaN        NaN            NaN

# %%
sex_age = AS1_01_EXAMINEE[["AS1_SEX", "AS1_AGE"]]
drink = AS1_03_DRSM[["AS1_DRINK", "AS1_TOTALC"]]

df = pd.concat([df, sex_age, drink, AS1_17_FFQWEIGHT], axis=1)

df.head()
# Out:
#                AS1_SEX  AS1_AGE  AS1_DRINK  AS1_TOTALC  AS1_W001  AS1_W002  \
# DIST_ID
# NIH23B1298125        1       53          3       23.15     220.0       0.0
# NIH23B1159376        2       44          1    77777.00     440.0       0.0
# NIH23B1785393        1       47          3       23.57     660.0       0.0
# NIH23B1463054        2       43          3        0.29     660.0       0.0
# NIH23B1751168        1       61          3       43.41     990.0       0.0
#
#                AS1_W003  AS1_W004  AS1_W005    AS1_W006  ...  AS1_W094  \
# DIST_ID                                                  ...
# NIH23B1298125     440.0       1.0      10.0   64.285714  ...       0.0
# NIH23B1159376       0.0       0.0       4.0   10.000000  ...       0.0
# NIH23B1785393       0.0       0.0      10.0  150.000000  ...       0.0
# NIH23B1463054       0.0       0.0      10.0  150.000000  ...       0.0
# NIH23B1751168       0.0       0.0       0.0   10.000000  ...       0.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10030 entries, NIH23B1298125 to NIH23B1160138
# Columns: 107 entries, AS1_SEX to AS1_W103
# dtypes: float64(104), int64(3)
# memory usage: 8.5+ MB
